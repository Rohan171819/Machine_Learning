# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohan171819/Data-Science/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
      # Linear Regression()Function
import pandas as pd
import numpy as np
from sklearn import linear_model
data=pd.read_csv("House.csv")
data
# Out:
#    Area   Price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
import matplotlib.pyplot as plt
plt.xlabel("Area")
plt.ylabel("Price in $")
plt.scatter(data["Area"],data["Price"],color="red")
plt.show()

# %%
d=linear_model.LinearRegression()  # Creating the object of linear Regression
d.fit(data[["Area"]],data["Price"])
b=d.predict([[3300]])
b
#data2=pd.read_csv("Area.csv")
#data2
#d.coef_
#d.intercept_
#new_d=180616.43835616432+135.78767123*3300
#a=d.predict(data2)
#a
#data2["Expected Price"]=a
#data2
#data2.to_csv("Area.csv")
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
import pandas as pd
from sklearn import linear_model
Income_data=pd.read_csv("Income.csv")
Income_data
# Out:
#     year  Per_Capita_Income
# 0   1970        3399.299037
# 1   1971        3768.297935
# 2   1972        4251.175484
# 3   1973        4804.463248
# 4   1974        5576.514583
# 5   1975        5998.144346
# 6   1976        7062.131392
# 7   1977        7100.126170
# 8   1978        7247.967035
# 9   1979        7602.912681
# 10  1980        8355.968120
# 11  1981        9434.390652
# 12  1982        9619.438377
# 13  1983       10416.536590
# 14  1984       10790.328720
# 15  1985       11018.955850
# 16  1986       11482.891530
# 17  1987       12974.806620
# 18  1988       15080.283450
# 19  1989       16426.725480
# 20  1990       16838.673200
# 21  1991       17266.097690
# 22  1992       16412.083090
# 23  1993       15875.586730
# 24  1994       15755.820270
# 25  1995       16369.317250
# 26  1996       16699.826680
# 27  1997       17310.757750
# 28  1998       16622.671870
# 29  1999       17581.024140
# 30  2000       18987.382410
# 31  2001       18601.397240
# ...

# %%
obj=linear_model.LinearRegression()
obj.fit(Income_data[["year"]],Income_data["Per_Capita_Income"])
p=obj.predict([[2020]])
values=pd.read_csv("Income2.csv")
values
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
#    Unnamed: 0  year  Estimated Per Capita Income
# 0           0  2017                 38803.298869
# 1           1  2018                 39631.763944
# 2           2  2019                 40460.229019
# 3           3  2020                 41288.694094
# 4           4  2021                 42117.159170
# 5           5  2022                 42945.624245
# 6           6  2023                 43774.089320
# 7           7  2024                 44602.554395
# 8           8  2025                 45431.019471

# %%
import matplotlib.pyplot as plt

plt.xlabel("Years")
plt.ylabel("Per Capita Income (US$)")
plt.scatter(Income_data[["year"]],Income_data[["Per_Capita_Income"]],color="red")
plt.plot(values["year"],values["Estimated Per Capita Income"])
plt.show()
