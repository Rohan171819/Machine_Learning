# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohan171819/Machine_Learning/blob/main/Bosten_Housing_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Data=pd.read_csv("/content/BostonHousing (1).csv")

# %%
plt.plot(Data)

# %%
from sklearn.model_selection import train_test_split
X=Data.iloc[:,0:14]
Y=Data.iloc[:,-1]
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,train_size=0.8,test_size=0.2,random_state=9)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Predictions=lr.predict(X_test)

# %%
plt.plot(Y_test,Predictions)
plt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
print(mean_squared_error(Y_test,Predictions))
print(mean_absolute_error(Y_test,Predictions))
# Out:
# 4.1637934720871404e-27
# 3.8156841520842635e-14
